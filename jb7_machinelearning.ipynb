# %% [markdown]
# <a href="https://colab.research.google.com/github/salwaa-hub/jb7_machinelearning/blob/main/jb7_machinelearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **DEEP LEARNING (CNN)** (Salwa Salsabila D - 4.3.23.2.25)

# %% [markdown]
# Dengan menggunakan pengetahuan tentang CNN pada bab ini, silakan susun Deep Neural Network sendiri untuk mendapatkan tingkat akurasi lbih dari 99% pada dataset berikut:
# https://www.kaggle.com/c/digit-recognizer/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# %%
# Load & Preprocess Data
train_df = pd.read_csv('train.csv')
X = train_df.drop('label', axis=1).values / 255.0
y = to_categorical(train_df['label'].values, num_classes=10)
X = X.reshape(-1, 28, 28, 1)

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
# Visualize Sample Data
plt.figure(figsize=(6,6))
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(X_train[i].reshape(28,28), cmap='gray')
    plt.title(f"Label: {np.argmax(y_train[i])}")
    plt.axis('off')
plt.tight_layout()
plt.show()

# %%
# Augmentation
datagen = ImageDataGenerator(
    rotation_range=10,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1
)
datagen.fit(X_train)

# %%
# Build CNN Model
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(28,28,1)),
    BatchNormalization(),
    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Dropout(0.25),

    Conv2D(64, (3,3), activation='relu'),
    BatchNormalization(),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Dropout(0.25),

    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

model.compile(optimizer=Adam(0.001), loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Train the Model
history = model.fit(datagen.flow(X_train, y_train, batch_size=64),
                    epochs=50,
                    validation_data=(X_val, y_val),
                    callbacks=[EarlyStopping(patience=10, restore_best_weights=True),
                               ReduceLROnPlateau(patience=5)])
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 108s 176ms/step - accuracy: 0.6624 - loss: 1.0560 - val_accuracy: 0.9800 - val_loss: 0.0784 - learning_rate: 0.0010
# Epoch 2/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 104s 176ms/step - accuracy: 0.9349 - loss: 0.2096 - val_accuracy: 0.9874 - val_loss: 0.0404 - learning_rate: 0.0010
# Epoch 3/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 108s 183ms/step - accuracy: 0.9587 - loss: 0.1338 - val_accuracy: 0.9869 - val_loss: 0.0415 - learning_rate: 0.0010
# Epoch 4/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 108s 183ms/step - accuracy: 0.9667 - loss: 0.1137 - val_accuracy: 0.9886 - val_loss: 0.0387 - learning_rate: 0.0010
# Epoch 5/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 106s 180ms/step - accuracy: 0.9724 - loss: 0.0931 - val_accuracy: 0.9905 - val_loss: 0.0353 - learning_rate: 0.0010
# Epoch 6/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 107s 181ms/step - accuracy: 0.9750 - loss: 0.0888 - val_accuracy: 0.9905 - val_loss: 0.0327 - learning_rate: 0.0010
# Epoch 7/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 106s 179ms/step - accuracy: 0.9759 - loss: 0.0841 - val_accuracy: 0.9890 - val_loss: 0.0337 - learning_rate: 0.0010
# Epoch 8/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 106s 179ms/step - accuracy: 0.9784 - loss: 0.0741 - val_accuracy: 0.9919 - val_loss: 0.0239 - learning_rate: 0.0010
# Epoch 9/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 106s 179ms/step - accuracy: 0.9800 - loss: 0.0694 - val_accuracy: 0.9921 - val_loss: 0.0281 - learning_rate: 0.0010
# Epoch 10/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 105s 178ms/step - accuracy: 0.9803 - loss: 0.0690 - val_accuracy: 0.9931 - val_loss: 0.0215 - learning_rate: 0.0010
# Epoch 11/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 147s 186ms/step - accuracy: 0.9825 - loss: 0.0613 - val_accuracy: 0.9910 - val_loss: 0.0269 - learning_rate: 0.0010
# Epoch 12/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 106s 180ms/step - accuracy: 0.9820 - loss: 0.0635 - val_accuracy: 0.9910 - val_loss: 0.0277 - learning_rate: 0.0010
# Epoch 13/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 109s 185ms/step - accuracy: 0.9800 - loss: 0.0699 - val_accuracy: 0.9924 - val_loss: 0.0271 - learning_rate: 0.0010
# Epoch 14/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 108s 183ms/step - accuracy: 0.9850 - loss: 0.0564 - val_accuracy: 0.9938 - val_loss: 0.0213 - learning_rate: 0.0010
# Epoch 15/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 108s 183ms/step - accuracy: 0.9843 - loss: 0.0537 - val_accuracy: 0.9929 - val_loss: 0.0236 - learning_rate: 0.0010
# Epoch 16/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 111s 187ms/step - accuracy: 0.9846 - loss: 0.0546 - val_accuracy: 0.9926 - val_loss: 0.0246 - learning_rate: 0.0010
# Epoch 17/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 107s 180ms/step - accuracy: 0.9870 - loss: 0.0455 - val_accuracy: 0.9914 - val_loss: 0.0258 - learning_rate: 0.0010
# Epoch 18/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 111s 188ms/step - accuracy: 0.9857 - loss: 0.0527 - val_accuracy: 0.9938 - val_loss: 0.0197 - learning_rate: 0.0010
# Epoch 19/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 111s 188ms/step - accuracy: 0.9855 - loss: 0.0488 - val_accuracy: 0.9926 - val_loss: 0.0218 - learning_rate: 0.0010
# Epoch 20/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 107s 182ms/step - accuracy: 0.9861 - loss: 0.0487 - val_accuracy: 0.9929 - val_loss: 0.0224 - learning_rate: 0.0010
# Epoch 21/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 110s 187ms/step - accuracy: 0.9870 - loss: 0.0432 - val_accuracy: 0.9926 - val_loss: 0.0220 - learning_rate: 0.0010
# Epoch 22/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 110s 187ms/step - accuracy: 0.9881 - loss: 0.0421 - val_accuracy: 0.9905 - val_loss: 0.0330 - learning_rate: 0.0010
# Epoch 23/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 142s 186ms/step - accuracy: 0.9862 - loss: 0.0467 - val_accuracy: 0.9940 - val_loss: 0.0243 - learning_rate: 0.0010
# Epoch 24/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 108s 182ms/step - accuracy: 0.9893 - loss: 0.0367 - val_accuracy: 0.9945 - val_loss: 0.0222 - learning_rate: 1.0000e-04
# Epoch 25/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 106s 179ms/step - accuracy: 0.9905 - loss: 0.0339 - val_accuracy: 0.9948 - val_loss: 0.0209 - learning_rate: 1.0000e-04
# Epoch 26/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 111s 188ms/step - accuracy: 0.9914 - loss: 0.0321 - val_accuracy: 0.9943 - val_loss: 0.0190 - learning_rate: 1.0000e-04
# Epoch 27/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 106s 180ms/step - accuracy: 0.9916 - loss: 0.0266 - val_accuracy: 0.9940 - val_loss: 0.0200 - learning_rate: 1.0000e-04
# Epoch 28/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 107s 181ms/step - accuracy: 0.9919 - loss: 0.0298 - val_accuracy: 0.9943 - val_loss: 0.0201 - learning_rate: 1.0000e-04
# Epoch 29/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 107s 181ms/step - accuracy: 0.9921 - loss: 0.0275 - val_accuracy: 0.9940 - val_loss: 0.0186 - learning_rate: 1.0000e-04
# Epoch 30/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 108s 183ms/step - accuracy: 0.9928 - loss: 0.0231 - val_accuracy: 0.9943 - val_loss: 0.0196 - learning_rate: 1.0000e-04
# Epoch 31/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 106s 180ms/step - accuracy: 0.9933 - loss: 0.0206 - val_accuracy: 0.9943 - val_loss: 0.0207 - learning_rate: 1.0000e-04
# Epoch 32/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 106s 179ms/step - accuracy: 0.9923 - loss: 0.0273 - val_accuracy: 0.9938 - val_loss: 0.0200 - learning_rate: 1.0000e-04
# Epoch 33/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 108s 182ms/step - accuracy: 0.9936 - loss: 0.0223 - val_accuracy: 0.9945 - val_loss: 0.0203 - learning_rate: 1.0000e-04
# Epoch 34/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 141s 180ms/step - accuracy: 0.9931 - loss: 0.0239 - val_accuracy: 0.9940 - val_loss: 0.0199 - learning_rate: 1.0000e-04
# Epoch 35/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 142s 180ms/step - accuracy: 0.9927 - loss: 0.0233 - val_accuracy: 0.9940 - val_loss: 0.0198 - learning_rate: 1.0000e-05
# Epoch 36/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 106s 180ms/step - accuracy: 0.9929 - loss: 0.0247 - val_accuracy: 0.9948 - val_loss: 0.0198 - learning_rate: 1.0000e-05
# Epoch 37/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 104s 175ms/step - accuracy: 0.9943 - loss: 0.0187 - val_accuracy: 0.9948 - val_loss: 0.0197 - learning_rate: 1.0000e-05
# Epoch 38/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 106s 180ms/step - accuracy: 0.9936 - loss: 0.0202 - val_accuracy: 0.9948 - val_loss: 0.0196 - learning_rate: 1.0000e-05
# Epoch 39/50
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 109s 185ms/step - accuracy: 0.9935 - loss: 0.0226 - val_accuracy: 0.9948 - val_loss: 0.0194 - learning_rate: 1.0000e-05

# %%
# Evaluate Performance
val_loss, val_acc = model.evaluate(X_val, y_val)
print(f"Validation Accuracy: {val_acc * 100:.2f}%")
# Out:
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9927 - loss: 0.0230
# Validation Accuracy: 99.40%

# %%
# Plot Accuracy and Loss
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title("Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.show()

plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title("Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Confusion Matrix
val_preds = model.predict(X_val)
val_labels = np.argmax(y_val, axis=1)
val_preds_labels = np.argmax(val_preds, axis=1)

cm = confusion_matrix(val_labels, val_preds_labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap='Blues', xticks_rotation='vertical')
plt.title("Confusion Matrix")
plt.show()
# Out:
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 7s 47ms/step

# %%
# Prepare Submission
test_df = pd.read_csv('test.csv')
X_test = test_df.values / 255.0
X_test = X_test.reshape(-1, 28, 28, 1)

pred = model.predict(X_test)
pred_labels = np.argmax(pred, axis=1)

submission = pd.DataFrame({
    "ImageId": np.arange(1, len(pred_labels) + 1),
    "Label": pred_labels
})
submission.to_csv("submission.csv", index=False)
# Out:
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 20s 23ms/step

# %%
# Visualisasi 9 gambar test pertama dengan prediksi
plt.figure(figsize=(8,8))
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(X_test[i].reshape(28,28), cmap='gray')
    plt.title(f"Submited: {pred_labels[i]}")
    plt.axis('off')
plt.tight_layout()
plt.show()
